# %% [markdown]
# ## Read STARBUCKS Data

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Ulsan_STARBUCKS_list.csv')
df.head()
# Out:
#    Unnamed: 0     s_name        lat         lot sido_name gugun_name  \
# 0           0       울산태화  35.550548  129.298364        울산         중구
# 1           1       울산옥동  35.535513  129.289651        울산         남구
# 2           2  울산시청사거리DT  35.537276  129.313613        울산         남구
# 3           3    울산성남삼거리  35.553215  129.320479        울산         중구
# 4           4      울산성남동  35.553969  129.321190        울산         중구
#
#                          doro_address           tel
# 0  울산광역시 중구 신기길 103, (1층,2층 전체) (태화동)  052-248-6589
# 1               울산광역시 남구 문수로 329 (옥동)  052-227-7982
# 2               울산광역시 남구 중앙로 182 (달동)  052-273-3312
# 3            울산광역시 중구 젊음의2거리 33 (성남동)  052-212-3346
# 4             울산광역시 중구 젊음의거리 74 (성남동)  052-248-1984

# %% [markdown]
# ## Length Calculating Function between two point

# %%
def get_length(lat1,lon1,lat2,lon2):
    R = 6371e3
    lat1 *= np.pi / 180
    lon1 *= np.pi / 180
    lat2 *= np.pi / 180
    lon2 *= np.pi / 180
    d_lat = lat2 - lat1
    d_lon = lon2 - lon1
    a = np.sin(d_lat/2) ** 2 + np.cos(lat1) * np.cos(lat2) * np.sin(d_lon/2) ** 2
    c = 2 * np.arctan2(a**0.5, (1-a) ** 0.5)
    d = R * c
    return d

# %% [markdown]
# ## Labeling the Data

# %% [markdown]
# <img src="https://trello-attachments.s3.amazonaws.com/59103d52b56a24582f00dc97/5aebc38103119846a74f765c/79486491dafa196b8b2a19c542e0bd9f/image.png"></img>

# %%
get_length(35.550548,129.298364,35.5355131,129.2896507)
# Out:
# 1848.3591079179876

# %%
final_data = pd.read_csv('unlabled_final_data.csv')

# %%
final_data = final_data.drop(['Unnamed: 0'],axis=1)

# %%
final_data['distance_to_SB'] = 0

# %%
final_data.iloc[0]['latitude']
# Out:
# 35.38095868063523

# %%
df.iloc[0]['lot']
# Out:
# 129.298364

# %%
# Calculating minimum distance to STARBUCS from each unit cell
for i in range(len(final_data)):
    min_distance = 1e10
    for j in range(len(df)):
        distance = get_length(final_data.iloc[i]['latitude'],final_data.iloc[i]['longitude'],
                             df.iloc[j]['lat'], df.iloc[j]['lot'])
        if(distance < min_distance):
            min_distance = distance
    final_data.loc[i,'distance_to_SB'] = min_distance

# %%
final_data = final_data.sort_values(by = ['distance_to_SB'])
final_data.head()
# Out:
#         PR_per_PY   latitude   longitude    SB_score  CLSS  SB_worker_score  \
# 319  4.753507e+06  35.537216  129.313418   37.268609     4         7.587481
# 341  5.387504e+06  35.539665  129.336618   91.735068     6        15.203293
# 295  9.863784e+06  35.535664  129.290234    9.856892     4         0.626328
# 445  3.807190e+06  35.550001  129.298185  200.612922     5         0.951267
# 258  6.450355e+06  35.532734  129.311139   36.182702     7         2.805681
#
#      distance_to_SB
# 319       18.845226
# 341       23.895260
# 295       55.361825
# 445       62.919465
# 258       78.872308

# %%
# 300m is affordable when considering go to walk
criteria = 500

# %%
final_data['y_label'] = final_data['distance_to_SB'].apply(lambda x : int(x < criteria))
final_data.head()
# Out:
#         PR_per_PY   latitude   longitude    SB_score  CLSS  SB_worker_score  \
# 319  4.753507e+06  35.537216  129.313418   37.268609     4         7.587481
# 341  5.387504e+06  35.539665  129.336618   91.735068     6        15.203293
# 295  9.863784e+06  35.535664  129.290234    9.856892     4         0.626328
# 445  3.807190e+06  35.550001  129.298185  200.612922     5         0.951267
# 258  6.450355e+06  35.532734  129.311139   36.182702     7         2.805681
#
#      distance_to_SB  y_label
# 319       18.845226        1
# 341       23.895260        1
# 295       55.361825        1
# 445       62.919465        1
# 258       78.872308        1

# %%
final_data = final_data.drop(['distance_to_SB'], axis=1)

# %%
final_data[['latitude','longitude','SB_score','CLSS','SB_worker_score','PR_per_PY','y_label']].to_csv('final_data.csv')

# %%
len(final_data[final_data['y_label'] == 1])
# Out:
# 111

# %%
len(final_data[final_data['y_label'] == 0])
# Out:
# 599

# %% [markdown]
# There are fifty data for y=1 and 660 for y=0

# %% [markdown]
# ## Conducting PCA(Principal Component Analysis) to remove collinearity of each feature

# %% [markdown]
# Not for component reduction, to eleminate the collinearity from each features

# %% [markdown]
# ### Standardizing the Dataset

# %% [markdown]
# Each features were measured on different scales, it makes sense to standardize the data.

# %% [markdown]
# Although all featrues are real valued, let us continue with the transformation of the data onto unist scale (mean=0 and variance = 1)

# %%
# changing column order for calculation convinience
col = list(final_data.columns[1:-1]) + list(final_data.columns[[0]])+ list(final_data.columns[[-1]])

# %%
final_data = final_data[col]
final_data = final_data.reindex(list(range(len(final_data))))
final_data.head()
# Out:
#     latitude   longitude    SB_score  CLSS  SB_worker_score     PR_per_PY  \
# 0  35.380959  129.341694   29.796767     3        11.287944  1.879607e+06
# 1  35.383626  129.345041   78.290981     4         3.440323  2.439039e+06
# 2  35.401375  129.288085  106.704431     4         0.932416  2.319935e+06
# 3  35.404102  129.285927   61.260468     2         5.867073  3.380989e+06
# 4  35.404126  129.283725   64.346015     4         3.628084  2.211868e+06
#
#    y_label
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
from sklearn.preprocessing import StandardScaler
ts = StandardScaler().fit_transform([[1],[2],[3]])
ts
# Out:
# array([[-1.22474487],
#        [ 0.        ],
#        [ 1.22474487]])

# %%
std_data = StandardScaler().fit_transform(final_data[col[2:-1]])

# %%
std_data[:5]
# Out:
# array([[-0.90813605, -0.84750034, -0.00905472, -1.30042319],
#        [ 0.09924468,  0.05463645, -0.35778148, -0.96794886],
#        [ 0.68948337,  0.05463645, -0.46922599, -1.03873314],
#        [-0.25453383, -1.74963714, -0.24994336, -0.40814129],
#        [-0.1904371 ,  0.05463645, -0.34943791, -1.10295825]])

# %% [markdown]
# ### Calculating Covariance Matrix

# %%
mean_vec = np.mean(std_data, axis=0)
cov_mat = (std_data - mean_vec).T.dot((std_data - mean_vec)) / (std_data.shape[0]-1)
print('Covariance matrix \n%s' %cov_mat)
# Out:
# Covariance matrix
# [[ 1.00141044  0.10146854 -0.08911173 -0.03577124]
#  [ 0.10146854  1.00141044  0.07712556  0.25497472]
#  [-0.08911173  0.07712556  1.00141044  0.06958799]
#  [-0.03577124  0.25497472  0.06958799  1.00141044]]

# %% [markdown]
# Eigendecomposition of the raw data based on the cov_mat

# %%
eig_vals, eig_vecs = np.linalg.eig(cov_mat)

print('Eigenvectors \n%s' %eig_vecs)
print('\nEigenvalues \n%s' %eig_vals)
# Out:
# Eigenvectors
# [[-0.35775222  0.49760668  0.78807568  0.05777256]
#  [ 0.69184844  0.03055818  0.245034    0.67850591]
#  [-0.14577588  0.74912414 -0.5625032   0.31804491]
#  [-0.61000695 -0.43619584 -0.04985194  0.65965104]]
#
# Eigenvalues
# [0.70787795 0.90484465 1.09882765 1.2940915 ]

# %% [markdown]
# Check the orthogonality

# %%
for ev in eig_vecs:
    np.testing.assert_array_almost_equal(1.0, np.linalg.norm(ev))
print('Everything ok!')
# Out:
# Everything ok!

# %% [markdown]
# Sorting and Print Eigenvalues

# %%
# Make a list of (eigenvalue, eigenvector) tuples
eig_pairs = [(np.abs(eig_vals[i]), eig_vecs[:,i]) for i in range(len(eig_vals))]

# Sort the (eigenvalue, eigenvector) tuples from high to low
eig_pairs.sort()
eig_pairs.reverse()

# Visually confirm that the list is correctly sorted by decreasing eigenvalues
print('Eigenvalues in descending order:')
for i in eig_pairs:
    print(i[0])
# Out:
# Eigenvalues in descending order:
# 1.2940914967709773
# 1.0988276535356092
# 0.904844646600935
# 0.7078779520346523

# %% [markdown]
# Every feature has significance variance

# %% [markdown]
# ### Calculating PC Score

# %%
reduction_eig_vec = np.matrix(eig_vecs).transpose()
reduction_eig_vec
# Out:
# matrix([[-0.35775222,  0.69184844, -0.14577588, -0.61000695],
#         [ 0.49760668,  0.03055818,  0.74912414, -0.43619584],
#         [ 0.78807568,  0.245034  , -0.5625032 , -0.04985194],
#         [ 0.05777256,  0.67850591,  0.31804491,  0.65965104]])

# %%
pc_score = std_data * reduction_eig_vec
col_name = []
for i in range(4):
    col_name.append('PC ' + str(i+1))
score_df = pd.DataFrame(pc_score,columns = col_name)
print('Matrix Size : ', score_df.shape[0], ' x ', score_df.shape[1])
score_df.head()
# Out:
# Matrix Size :  710  x  4
#        PC 1      PC 2      PC 3      PC 4
# 0 -0.179099 -1.538754 -0.910998  0.066271
# 1 -0.346197 -0.674096 -0.080136 -0.705045
# 2 -0.649273 -0.341075 -0.126003 -1.106231
# 3 -1.000125 -0.567735 -1.262804  0.661681
# 4 -0.243787 -0.964072 -0.085540 -0.617812

# %%
pc_data = pd.concat([final_data[col[0:2]], score_df, final_data[col[-1]]], axis=1)
pc_data.head()
# Out:
#     latitude   longitude      PC 1      PC 2      PC 3      PC 4  y_label
# 0  35.380959  129.341694 -0.179099 -1.538754 -0.910998  0.066271        0
# 1  35.383626  129.345041 -0.346197 -0.674096 -0.080136 -0.705045        0
# 2  35.401375  129.288085 -0.649273 -0.341075 -0.126003 -1.106231        0
# 3  35.404102  129.285927 -1.000125 -0.567735 -1.262804  0.661681        0
# 4  35.404126  129.283725 -0.243787 -0.964072 -0.085540 -0.617812        0

# %%
pc_data.to_csv('pc_data.csv')

# %% [markdown]
# ## Logistic Regression to PC_Data

# %%
pc_data.groupby('y_label').mean()
# Out:
#           latitude   longitude      PC 1      PC 2      PC 3      PC 4
# y_label
# 0        35.538912  129.323966 -0.086510 -0.014109 -0.034898 -0.025913
# 1        35.545894  129.316214  0.466843  0.076137  0.188322  0.139834

# %%
x_col = pc_data.columns[2:-1]
X = pc_data[x_col]
y = pc_data['y_label']

# %%
from sklearn.cross_validation import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

'''
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=0)
logreg = LogisticRegression() # class
logreg.fit(X_train, y_train)
'''

logreg = LogisticRegression() # class
logreg.fit(X, y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
y_pred = logreg.predict(X)
print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(logreg.score(X_test, y_test)))
# Out:
# Accuracy of logistic regression classifier on test set: 0.89

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, y_pred)
print(confusion_matrix)
# Out:
# [[63  0]
#  [ 8  0]]

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.89      1.00      0.94        63
#           1       0.00      0.00      0.00         8
#
# avg / total       0.79      0.89      0.83        71
# c:\users\wnsvy\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
import matplotlib.pyplot as plt
% matplotlib inline
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(y_test, logreg.predict(X_test))
fpr, tpr, thresholds = roc_curve(y_test, logreg.predict_proba(X_test)[:,1])
plt.figure(figsize=(14,7))
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()

# %%
# Weight for each PC features
logreg.coef_
# Out:
# array([[ 0.44371505, -0.08596013,  0.23485439,  0.12930499]])

# %%
# Probability Fail, Pass
logreg.predict_proba(X.iloc[0].values.reshape(-1,4))
# Out:
# array([[0.86713756, 0.13286244]])

# %%
pc_data['prob'] = pd.Series(pc_data.index).apply(lambda x : logreg.predict_proba(X.iloc[x].values.reshape(-1,4))[0][1])

# %%
pc_data.sort_values(by = 'prob', ascending=False)
# Out:
#       latitude   longitude       PC 1      PC 2      PC 3      PC 4  y_label  \
# 265  35.533466  129.326590  14.605777  4.444692 -7.647563 -0.422127        0
# 270  35.533623  129.312257   7.139199  2.245061 -4.076262  1.175745        1
# 240  35.531063  129.298982   2.628217  1.510738  3.766897  1.175329        0
# 472  35.553499  129.308169   2.208653 -0.036678  3.200100 -0.385130        0
# 251  35.531964  129.298996   1.696702  1.511072  3.352154  1.468602        0
# 263  35.532889  129.296806   1.611792  1.633888  3.449353  1.547272        0
# 284  35.534692  129.296835   1.625849  2.459746  3.975210  0.456081        0
# 65   35.487798  129.212315  -1.504180 -0.810879 -2.359019  0.255177        0
# 85   35.494558  129.418537  -1.354827  1.970639 -0.361862 -2.154234        0
# 580  35.564813  129.344759  -1.452276  0.379216 -1.749300 -0.623297        0
# 475  35.553962  129.347887  -1.739595  0.542426 -1.351512 -0.256471        0
# 361  35.541369  129.423774  -1.402905  2.436320  0.211102 -3.260639        0
# 427  35.548726  129.332357  -1.528145  1.228812 -0.480964 -2.608469        0
# 246  35.531676  129.325458  -1.656634  2.224305 -0.747147 -1.074258        0
# 232  35.530774  129.325443  -1.772984  1.497378 -1.347143 -0.220158        0
# 554  35.559811  129.222226  -1.748645  2.499656 -0.523255 -2.843612        0
# 443  35.549846  129.312522  -2.248343  4.205908 -0.765281  0.426601        0
# 441  35.549688  129.326858  -1.539775  1.427076 -1.621669 -2.498704        0
# 216  35.529861  129.326531  -2.371809  4.085080 -0.443650 -3.306727        0
# 78   35.491855  129.418490  -2.469147  1.864030 -1.989966 -2.092631        0
# 75   35.490953  129.418474  -3.031107  2.641724 -2.109465 -2.884454        0
#
#          prob
# 265  0.925861
# 270  0.609731
# 240  0.586535
# 472  0.490406
# 251  0.469245
# 263  0.465452
# 284  0.445033
# 266  0.428027
# 490  0.422017
# 337  0.408590
# 238  0.402077
# 668  0.401841
# 258  0.394828
# 241  0.390040
# 194  0.371811
# 224  0.371721
# 267  0.346364
# 362  0.341808
# 201  0.337448
# 471  0.332342
# 601  0.328607
# 682  0.328336
# 380  0.326315
# 255  0.325002
# 360  0.320952
# 268  0.317816
# 252  0.311153
# 299  0.308036
# 195  0.307902
# 379  0.307879
# ..        ...
# 340  0.070600
# 697  0.070151
# 393  0.069627
# 84   0.069458
# 564  0.068829
# 507  0.067654
# 260  0.066819
# 569  0.066389
# 524  0.061672
# 8    0.061482
# 123  0.060862
# 683  0.060790
# 392  0.060228
# 603  0.059991
# 23   0.059080
# 593  0.056445
# 65   0.055093
# 85   0.054300
# 580  0.052564
# 475  0.052531
# 361  0.050822
# 427  0.049396
# 246  0.049081
# 232  0.048174
# 554  0.038991
# 443  0.038902
# 441  0.037937
# 216  0.025120
# 78   0.023728
# 75   0.015311
#
# [710 rows x 8 columns]

# %%
pc_data.to_csv('with_PCA_result.csv')

# %% [markdown]
# # Logistic Regression without PCA

# %%
final_data.columns[2:-1]
# Out:
# Index(['SB_score', 'CLSS', 'SB_worker_score', 'PR_per_PY'], dtype='object')

# %%
std_data[:5]
# Out:
# array([[-0.90813605, -0.84750034, -0.00905472, -1.30042319],
#        [ 0.09924468,  0.05463645, -0.35778148, -0.96794886],
#        [ 0.68948337,  0.05463645, -0.46922599, -1.03873314],
#        [-0.25453383, -1.74963714, -0.24994336, -0.40814129],
#        [-0.1904371 ,  0.05463645, -0.34943791, -1.10295825]])

# %%
col_name = final_data.columns[2:-1]
std_df = pd.DataFrame(std_data,columns = col_name)
print('Matrix Size : ', std_df.shape[0], ' x ', std_df.shape[1])
std_df.head()
# Out:
# Matrix Size :  710  x  4
#    SB_score      CLSS  SB_worker_score  PR_per_PY
# 0 -0.908136 -0.847500        -0.009055  -1.300423
# 1  0.099245  0.054636        -0.357781  -0.967949
# 2  0.689483  0.054636        -0.469226  -1.038733
# 3 -0.254534 -1.749637        -0.249943  -0.408141
# 4 -0.190437  0.054636        -0.349438  -1.102958

# %%
std_final_data = pd.concat([final_data[col[0:2]], std_df, final_data[col[-1]]], axis=1)
std_final_data.head()
# Out:
#     latitude   longitude  SB_score      CLSS  SB_worker_score  PR_per_PY  \
# 0  35.380959  129.341694 -0.908136 -0.847500        -0.009055  -1.300423
# 1  35.383626  129.345041  0.099245  0.054636        -0.357781  -0.967949
# 2  35.401375  129.288085  0.689483  0.054636        -0.469226  -1.038733
# 3  35.404102  129.285927 -0.254534 -1.749637        -0.249943  -0.408141
# 4  35.404126  129.283725 -0.190437  0.054636        -0.349438  -1.102958
#
#    y_label
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
std_final_data.to_csv('std_final_data.csv')

# %%
std_final_data.groupby('y_label').mean()
# Out:
#           latitude   longitude  SB_score      CLSS  SB_worker_score  PR_per_PY
# y_label
# 0        35.538912  129.323966  0.042082 -0.058319        -0.050712  -0.042763
# 1        35.545894  129.316214 -0.227091  0.314712         0.273661   0.230767

# %%
x_col = std_final_data.columns[2:-1]
X = std_final_data[x_col]
y = std_final_data['y_label']

# %%
from sklearn.cross_validation import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=0)
lr = LogisticRegression() # class
lr.fit(X, y)
# Out:
# c:\users\wnsvy\anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
y_pred = lr.predict(X)
print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(lr.score(X, y)))
# Out:
# Accuracy of logistic regression classifier on test set: 0.84

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y, y_pred)
print(confusion_matrix)
# Out:
# [[597   2]
#  [110   1]]

# %%
from sklearn.metrics import classification_report
print(classification_report(y, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.84      1.00      0.91       599
#           1       0.33      0.01      0.02       111
#
# avg / total       0.76      0.84      0.77       710

# %%
import matplotlib.pyplot as plt
% matplotlib inline
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(y, lr.predict(X))
fpr, tpr, thresholds = roc_curve(y, lr.predict_proba(X)[:,1])
plt.figure(figsize=(14,7))
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()

# %%
# Weight for each PC features
lr.coef_
# Out:
# array([[-0.32704902,  0.33214791,  0.19087741,  0.1377166 ]])

# %%
# Probability Fail, Pass
lr.predict_proba(X.iloc[0].values.reshape(-1,4))
# Out:
# array([[0.91499637, 0.08500363]])

# %%
std_final_data['prob'] = pd.Series(std_final_data.index).apply(lambda x : lr.predict_proba(X.iloc[x].values.reshape(-1,4))[0][1])

# 8    35.406865  129.280465  1.589684 -0.847500        -0.351637  -0.962486
# 683  35.631455  129.350294  0.846314 -1.749637        -0.322918  -0.641578
# 123  35.510767  129.419925  2.666938  0.054636        -0.352019  -0.636098
# 392  35.545050  129.255090  2.770783  0.054636        -0.363361  -0.436489
# 603  35.567731  129.241102  2.746063  0.054636        -0.351928  -0.550765
# 23   35.472131  129.409327  0.924387 -1.749637        -0.420948  -0.530392
# 593  35.566591  129.346996  0.925900 -1.749637        -0.493851  -0.798027
# 65   35.487798  129.212315  0.165347 -2.651774        -0.069867  -1.219033
# 85   35.494558  129.418537  3.214924  0.054636        -0.273891  -0.277312
# 475  35.553962  129.347887  1.351087 -1.749637        -0.465004  -0.331484
# 580  35.564813  129.344759  1.417136 -1.749637        -0.036523  -0.794116
# 361  35.541369  129.423774  4.145695  0.956773        -0.464811  -0.511736
# 246  35.531676  129.325458  2.895767 -0.847500        -0.286696   0.467234
# 427  35.548726  129.332357  3.058146  0.054636        -0.502612  -1.128176
# 232  35.530774  129.325443  2.000926 -1.749637        -0.261589   0.339870
# 443  35.549846  129.312522  3.565531 -1.749637        -0.332068   2.761855
# 554  35.559811  129.222226  4.165866  0.054636        -0.329472  -0.447203
# 441  35.549688  129.326858  3.298805 -0.847500         0.172982  -1.284714
# 216  35.529861  129.326531  5.756576  0.054636        -0.453780   0.312339
# 78   35.491855  129.418490  3.739578 -1.749637        -0.265440  -0.891198
# 75   35.490953  129.418474  4.979104 -1.749637        -0.411053  -0.956327
#
#      y_label      prob
# 265        0  0.924226
# 270        1  0.605157
# 240        0  0.579748
# 472        0  0.477551
# 251        0  0.463688
# 263        0  0.460356
# 284        0  0.439975
# 266        0  0.418879
# 490        0  0.409735
# 337        0  0.405145
# 238        1  0.391211
# 668        0  0.387227
# 241        0  0.386426
# 258        1  0.385346
# 194        0  0.363198
# 224        1  0.362210
# 267        0  0.339967
# 362        1  0.334305
# 201        0  0.328963
# 471        0  0.324067
# 682        0  0.322730
# 380        1  0.319795
# 601        0  0.317846
# 255        0  0.316654
# 360        0  0.314786
# 268        0  0.307754
# 252        0  0.307252
# 195        0  0.305464
# 299        1  0.304845
# 379        1  0.300932
# ..       ...       ...
# 620        0  0.068810
# 340        0  0.068768
# 697        0  0.067990
# 84         0  0.067792
# 564        0  0.066701
# 507        0  0.065540
# 260        0  0.065073
# 569        0  0.064602
# 524        0  0.061168
# 8          0  0.059524
# 683        0  0.059141
# 123        0  0.059089
# 392        0  0.058610
# 603        0  0.058309
# 23         0  0.057552
# 593        0  0.054833
# 65         0  0.053402
# 85         0  0.053015
# 475        0  0.051351
# 580        0  0.051179
# 361        0  0.049445
# 246        0  0.048435
# 427        0  0.047777
# 232        0  0.047534
# 443        0  0.039574
# 554        0  0.038136
# 441        0  0.036855
# 216        0  0.024914
# 78         0  0.023282
# 75         0  0.015088
#
# [710 rows x 8 columns]

# %%
std_final_data.to_csv('NO_PCA_result.csv')
